# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **BANELE DLUDLU**
#
# Data Analyst at Eswatini Bank

# %% [markdown]
# *I am interested in data science because I want to bring innovation in my country's economic sector and police investigations, I want to bring data driven solutions in this fields*

# %% [markdown]
# ### This code evaluates the sum of the first 5 numbers starting from 0

# %%
Sumx = 0+1+2+3+4
Sumx
# Out:
# 10

# %% [markdown]
# ---
#
# Numbered list
# 1. Banele
# 2. IBM
#
# ---
# - Julia
# - Python
